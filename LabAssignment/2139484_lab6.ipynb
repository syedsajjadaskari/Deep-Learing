# %% [markdown]
# #implementation of simpleRNN , LSTM and GRU

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from keras.models import Sequential
from keras.layers import SimpleRNN

# %%
# Define the RNN model
model = Sequential()
model.add(SimpleRNN(3, input_shape=(2, 1)))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  simple_rnn_2 (SimpleRNN)    (None, 3)                 15
#
# ...
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Generate some dummy data for demonstration purposes
import numpy as np
x_train = np.random.random((1000, 2, 1))
y_train = np.random.random((1000, 1))

# %%
# Fit the model on the dummy data
model.fit(x_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 1s 2ms/step - loss: 0.6757
# Epoch 2/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6069
# Epoch 3/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5486
# Epoch 4/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4988
# Epoch 5/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4550
# Epoch 6/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4156
# Epoch 7/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3807
# Epoch 8/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3494
# Epoch 9/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3214
# Epoch 10/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2960

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from keras.layers import LSTM
model = Sequential()
model.add(LSTM(3, input_shape=(2, 1)))

# %%
# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Generate some dummy data for demonstration purposes
import numpy as np
x_train = np.random.random((1000, 2, 1))
y_train = np.random.random((1000, 1))

# %%
# Fit the model on the dummy data
model.fit(x_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 2s 3ms/step - loss: 0.4163
# Epoch 2/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3916
# Epoch 3/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3683
# Epoch 4/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3462
# Epoch 5/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3251
# Epoch 6/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3042
# Epoch 7/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2840
# Epoch 8/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2640
# Epoch 9/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2447
# Epoch 10/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2254

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from keras.layers import GRU
model = Sequential()
model.add(GRU(3, input_shape=(2, 1)))

# %%
# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Generate some dummy data for demonstration purposes
import numpy as np
x_train = np.random.random((1000, 2, 1))
y_train = np.random.random((1000, 1))

# %%
# Fit the model on the dummy data
model.fit(x_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 2s 3ms/step - loss: 0.3178
# Epoch 2/10
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2729
# Epoch 3/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2323
# Epoch 4/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1959
# Epoch 5/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1637
# Epoch 6/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1369
# Epoch 7/10
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1166
# Epoch 8/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1024
# Epoch 9/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0937
# Epoch 10/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0889
